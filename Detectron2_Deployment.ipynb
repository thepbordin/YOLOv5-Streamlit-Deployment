# %% [markdown]
# <a href="https://colab.research.google.com/github/thepbordin/Obstacle-Detection-for-Blind-people-Deployment/blob/main/Detectron2_Deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Installing Detectron2

# %%
# !python -m pip install pyyaml==5.1 &> /dev/null
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git' &> /dev/null
# !pip install streamlit &> /dev/null
exit(0)

# %%
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# torch:  1.11 ; cuda:  cu113
# detectron2: 0.6

# %% [markdown]
# ## Detectron2 streamlit
# Thanks code from [Object Detection App with Streamlit and Detectron2 - Medium](https://medium.com/@bolarinwaoreoluwa24/object-detection-app-with-streamlit-and-detectron2-26776802cc00)

# %%
import shutil
shutil.rmtree('/content/Obstacle-Detection-for-Blind-people-Deployment')

# %%
# !git clone "https://github.com/thepbordin/Obstacle-Detection-for-Blind-people-Deployment.git"
# Out:
# fatal: destination path 'Obstacle-Detection-for-Blind-people-Deployment' already exists and is not an empty directory.

# %%
# !git clone -b test "https://github.com/thepbordin/Obstacle-Detection-for-Blind-people-Deployment.git"
# Out:
# Cloning into 'Obstacle-Detection-for-Blind-people-Deployment'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 44 (delta 13), reused 39 (delta 10), pack-reused 0
# Unpacking objects: 100% (44/44), done.

# %%
# !cp "/content/drive/Shareddrives/AI Builders/Model Checkpoints/Dataset3.0/model_final.pth" "/content/Obstacle-Detection-for-Blind-people-Deployment/model"

# %% [markdown]
# ## Setting up ngrok
# Thanks tutorial from [Create a runtime dashboard from Colab via Streamlit & Pyngrok](https://towardsdev.com/create-a-runtime-dashboard-from-colab-via-streamlit-pyngrok-3c5588cfcfc5)

# %%
# !pip install pyngrok &> /dev/null

# %% [markdown]
# ### Mount Google Drive For API Key

# %%
from google.colab import drive
drive.mount('/content/drive')

with open('/content/drive/MyDrive/API Keys/ngrok.txt') as f:
    apikey = f.read()
# Out:
# Mounted at /content/drive

# %%
from pyngrok import ngrok
# !ngrok authtoken $apikey
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
publ_url = ngrok.connect()
publ_url
# Out:
# <NgrokTunnel: "http://f2bb-35-231-111-34.ngrok.io" -> "http://localhost:80">

# %% [markdown]
# ##Start Streamlit!

# %%
# !streamlit run --server.port 80 /content/Obstacle-Detection-for-Blind-people-Deployment/codes/app.py
# Out:
# 2022-06-18 12:35:25.828 INFO    numexpr.utils: NumExpr defaulting to 2 threads.
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:80
#   External URL: http://35.231.111.34:80
#
# [06/18 12:35:51 d2.data.datasets.coco]: Loaded 1242 images in COCO format from /content/Obstacle-Detection-for-Blind-people-Deployment/model/train.json
# 2022-06-18 12:35:51.953 [Checkpointer] Loading from /content/Obstacle-Detection-for-Blind-people-Deployment/model/model_final.pth ...
# [06/18 12:35:52 d2.checkpoint.c2_model_loading]: Following weights matched with model:
# | Names in Model                                  | Names in Checkpoint                                                                                  | Shapes                                          |
# ...

# %% [markdown]
# TODO:
#
# *   Confidence Slider
# *   List item
